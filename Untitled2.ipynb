# %% [markdown]
# <a href="https://colab.research.google.com/github/chandraharshini/Machine-Learning-project-2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generate a synthetic dataset for demonstration
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Create a DataFrame
df = pd.DataFrame({'Feature': X.flatten(), 'Target': y.flatten()})

print("Generated synthetic dataset:")
display(df.head())
# Out:
# Generated synthetic dataset:
#     Feature    Target
# 0  0.749080  6.334288
# 1  1.901429  9.405278
# 2  1.463988  8.483724
# 3  1.197317  5.604382
# 4  0.312037  4.716440

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Feature']], df['Target'], test_size=0.2, random_state=42)

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Testing data shape: {X_test.shape}, {y_test.shape}")
# Out:
# Training data shape: (80, 1), (80,)
# Testing data shape: (20, 1), (20,)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print("Model training complete.")
print(f"Coefficient: {model.coef_[0]:.2f}")
print(f"Intercept: {model.intercept_:.2f}")
# Out:
# Model training complete.
# Coefficient: 2.80
# Intercept: 4.14

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 0.65
# R-squared (R2): 0.81

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_test.values.flatten(), y=y_test, label='Actual Values')
sns.lineplot(x=X_test.values.flatten(), y=y_pred, color='red', label='Predicted Values')
plt.title('Actual vs. Predicted Values')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Other Regression Algorithms
#
# Let's also try a couple of other regression algorithms: Decision Tree Regressor and Random Forest Regressor.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Decision Tree Regressor
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)
dt_y_pred = dt_model.predict(X_test)
dt_mse = mean_squared_error(y_test, dt_y_pred)
dt_r2 = r2_score(y_test, dt_y_pred)

print(f"\n--- Decision Tree Regressor ---")
print(f"Mean Squared Error (MSE): {dt_mse:.2f}")
print(f"R-squared (R2): {dt_r2:.2f}")

# Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)
rf_y_pred = rf_model.predict(X_test)
rf_mse = mean_squared_error(y_test, rf_y_pred)
rf_r2 = r2_score(y_test, rf_y_pred)

print(f"\n--- Random Forest Regressor ---")
print(f"Mean Squared Error (MSE): {rf_mse:.2f}")
print(f"R-squared (R2): {rf_r2:.2f}")
# Out:
# --- Decision Tree Regressor ---
# Mean Squared Error (MSE): 0.92
# R-squared (R2): 0.73
#
# --- Random Forest Regressor ---
# Mean Squared Error (MSE): 0.77
# R-squared (R2): 0.77

# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, ConfusionMatrixDisplay

# Generate synthetic classification data
X_clf, y_clf = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# Split data
X_train_clf, X_test_clf, y_train_clf, y_test_clf = train_test_split(X_clf, y_clf, test_size=0.2, random_state=42)

# Train a Logistic Regression model
clf_model = LogisticRegression(random_state=42)
clf_model.fit(X_train_clf, y_train_clf)
clf_y_pred = clf_model.predict(X_test_clf)
clf_y_proba = clf_model.predict_proba(X_test_clf)[:, 1]

print("Classification model training complete.")
# Out:
# Classification model training complete.

# %%
cm = confusion_matrix(y_test_clf, clf_y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test_clf, clf_y_proba)
roc_auc = roc_auc_score(y_test_clf, clf_y_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
